# %%
import pandas as pd
df=pd.read_excel("Sample - Superstore.xls")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Question 1: Find total number of orders in the dataset.
df['Order ID'].count()
# Out:
# np.int64(9994)

# %%
# Question 2: Find the earliest order date.
df['Order Date'].min()
# Out:
# Timestamp('2014-01-03 00:00:00')

# %%
# Question 3: Find the latest order date.
df['Order Date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
# Question 4: Find the total number of unique customers.
df.groupby('Customer ID')['Customer Name'].unique()
# Out:
# Customer ID
# AA-10315            [Alex Avila]
# AA-10375          [Allen Armold]
# AA-10480          [Andrew Allen]
# AA-10645         [Anna Andreadi]
# AB-10015         [Aaron Bergman]
#                     ...
# XP-21865          [Xylona Preis]
# YC-21895        [Yoseph Carroll]
# YS-21880         [Yana Sorensen]
# ZC-21910      [Zuschuss Carroll]
# ZD-21925    [Zuschuss Donatelli]
# Name: Customer Name, Length: 793, dtype: object

# %%
# Question 5: Find the total number of unique products sold.
df.groupby('Product ID')['Product Name'].unique()
# Out:
# Product ID
# FUR-BO-10000112    [Bush Birmingham Collection Bookcase, Dark Che...
# FUR-BO-10000330    [Sauder Camden County Barrister Bookcase, Plan...
# FUR-BO-10000362                 [Sauder Inglewood Library Bookcases]
# FUR-BO-10000468            [O'Sullivan 2-Shelf Heavy-Duty Bookcases]
# FUR-BO-10000711                          [Hon Metal Bookcases, Gray]
#                                          ...
# TEC-PH-10004912                  [Cisco SPA112 2 Port Phone Adapter]
# TEC-PH-10004922             [RCA Visys Integrated PBX 8-Line Router]
# TEC-PH-10004924    [SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" ...
# TEC-PH-10004959             [Classic Ivory Antique Telephone ZL1810]
# TEC-PH-10004977                                        [GE 30524EE4]
# Name: Product Name, Length: 1862, dtype: object

# %%
# Question 6: Find the total number of unique categories.
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Question 7: Find the total number of unique sub-categories.
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
# Question 8: Count number of orders in each region.
df.groupby('Region')['Order ID'].count()
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# Name: Order ID, dtype: int64

# %%
# Question 9: Count number of orders by state.
df.groupby('State')['Order ID'].count()
# Out:
# State
# Alabama                   61
# Arizona                  224
# Arkansas                  60
# California              2001
# Colorado                 182
# Connecticut               82
# Delaware                  96
# District of Columbia      10
# Florida                  383
# Georgia                  184
# Idaho                     21
# Illinois                 492
# Indiana                  149
# Iowa                      30
# Kansas                    24
# Kentucky                 139
# Louisiana                 42
# Maine                      8
# Maryland                 105
# Massachusetts            135
# Michigan                 255
# Minnesota                 89
# Mississippi               53
# Missouri                  66
# Montana                   15
# Nebraska                  38
# Nevada                    39
# New Hampshire             27
# New Jersey               130
# New Mexico                37
# New York                1128
# North Carolina           249
# North Dakota               7
# Ohio                     469
# Oklahoma                  66
# Oregon                   124
# Pennsylvania             587
# Rhode Island              56
# South Carolina            42
# South Dakota              12
# Tennessee                183
# Texas                    985
# Utah                      53
# Vermont                   11
# Virginia                 224
# Washington               506
# West Virginia              4
# Wisconsin                110
# Wyoming                    1
# Name: Order ID, dtype: int64

# %%
# Question 10: Count number of orders by city.
df.groupby('City')['Order ID'].count()
# Out:
# City
# Aberdeen        1
# Abilene         1
# Akron          21
# Albuquerque    14
# Alexandria     16
#                ..
# Woonsocket      4
# Yonkers        15
# York            5
# Yucaipa         1
# Yuma            4
# Name: Order ID, Length: 531, dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Question 11: Find the most common ship mode.
df['Ship Mode'].mode()[0]   # most common --> mode()
# Out:
# 'Standard Class'

# %%
# Question 12: Find the least common ship mode.
ship_mode_counts=df['Ship Mode'].value_counts()
least_common=ship_mode_counts.index[-1]
least_common
# Out:
# 'Same Day'

# %%
# Question 13: Count number of orders shipped with "Same Day" mode.
print(df[df['Ship Mode']=='Same Day']['Order ID'].count())
# Out:
# 543

# %%
# Question 14: Count number of orders shipped with "First Class".
print(df[df['Ship Mode']=='First Class']['Order ID'].count())
# Out:
# 1538

# %%
# Question 15: Count number of orders shipped with "Second Class".
print(df[df['Ship Mode']=='Second Class']['Order ID'].count())
# Out:
# 1945

# %%
# Question 16: Count number of orders shipped with "Standard Class".
print(df[df['Ship Mode']=='Standard Class']['Order ID'].count())
# Out:
# 5968

# %%
# Question 17: Find number of orders in each year.
df['Year'] = pd.to_datetime(df['Order Date']).dt.year
df.groupby('Year')['Order ID'].count()
# Out:
# Year
# 2014    1993
# 2015    2102
# 2016    2587
# 2017    3312
# Name: Order ID, dtype: int64

# %%
# Question 18: Find number of orders in each quarter.
df['Quarter'] = df['Order Date'].dt.quarter
df.groupby('Quarter')['Order ID'].count()
# Out:
# Quarter
# 1    1377
# 2    2120
# 3    2799
# 4    3698
# Name: Order ID, dtype: int64

# %%
# Question 19: Find number of orders in each month.
df['Month']=df['Order Date'].dt.month  # extract year
df.groupby('Month')['Order ID'].count()
# Out:
# Month
# 1      381
# 2      300
# 3      696
# 4      668
# 5      735
# 6      717
# 7      710
# 8      706
# 9     1383
# 10     819
# 11    1471
# 12    1408
# Name: Order ID, dtype: int64

# %%
# Question 20: Find number of orders in each weekday.
df['Weekday']=df['Order Date'].dt.day_name()  # or df['Weekday']=df['Order Date'].dt.weekday weekday-->dt.weekday returns 0 for Monday, 1 for Tuesday … 6 for Sunday.
df.groupby('Weekday')['Order ID'].count()
# Out:
# Weekday
# Friday       1818
# Monday       1871
# Saturday     1655
# Sunday       1710
# Thursday     1463
# Tuesday      1106
# Wednesday     371
# Name: Order ID, dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Year',
#        'Quarter', 'Month', 'Weekday'],
#       dtype='object')

# %%
# Question 21: Count orders with discount applied.
with_discount=df[df['Discount']>0]
with_discount.groupby('Discount')['Order ID'].count()
# Out:
# Discount
# 0.10      94
# 0.15      52
# 0.20    3657
# 0.30     227
# 0.32      27
# 0.40     206
# 0.45      11
# 0.50      66
# 0.60     138
# 0.70     418
# 0.80     300
# Name: Order ID, dtype: int64

# %%
# Question 22: Count orders without discount.
print(df[df['Discount']==0]['Order ID'].count())
# Out:
# 4798

# %%
# Question 23: Count orders where discount = 0.
print(df[df['Discount']==0]['Order ID'].count())
# Out:
# 4798

# %%
# Question 24: Count orders where discount > 0.2.
print(df[df['Discount']>0.2]['Order ID'].count())
# Out:
# 1393

# %%
# Question 25: Count orders where discount = 0.5.
print(df[df['Discount']>0.5]['Order ID'].count())
# Out:
# 856

# %%
# Question 26: Find maximum discount given.
print(df['Discount'].max())
# Out:
# 0.8

# %%
# Question 27: Find minimum discount given.
print(df['Discount'].min())
# Out:
# 0.0

# %%
# Question 28: Count orders where profit < 0.
print(df[df['Profit']<0]['Order ID'].count())
# Out:
# 1871

# %%
# Question 29: Count orders where profit = 0.
print(df[df['Profit']==0]['Order ID'].count())
# Out:
# 65

# %%
# Question 30: Count orders where profit > 100.
print(df[df['Profit']>100]['Order ID'].count())
# Out:
# 890

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Year',
#        'Quarter', 'Month', 'Weekday'],
#       dtype='object')

# %%
# Question 32: Find total quantity sold.
print(df['Quantity'].sum())
# Out:
# 37873

# %%
# Question 33: Find average quantity per order.
print(df['Quantity'].sum()/df['Order ID'].nunique())
# Out:
# 7.560990217608305

# %%
# Question 34: Find average sales per order.
print(df.groupby('Order ID')['Sales'].sum().mean())
# Out:
# 458.61466566180883

# %%
# Question 35: Find average profit per order.
print(df.groupby('Order ID')['Profit'].sum().mean())
# Out:
# 57.17648666400478

# %%
# Question 36: Find maximum sales in a single order.
print(df.groupby("Order ID")['Sales'].sum().max())
# Out:
# 23661.228

# %%
# Question 37: Find minimum sales in a single order.
print(df.groupby("Order ID")['Sales'].sum().min())
# Out:
# 0.5559999999999998

# %%
# Question 38: Find maximum profit in a single order
print(df.groupby("Order ID")['Profit'].sum().max())
# Out:
# 8762.389099999999

# %%
# Question 39: Find minimum profit in a single order.
print(df.groupby("Order ID")['Profit'].sum().min())
# Out:
# -6892.3748000000005

# %%
# Question 40: Find number of orders per customer.
df.groupby("Customer ID")['Order ID'].nunique()
# Out:
# Customer ID
# AA-10315     5
# AA-10375     9
# AA-10480     4
# AA-10645     6
# AB-10015     3
#             ..
# XP-21865    11
# YC-21895     5
# YS-21880     8
# ZC-21910    13
# ZD-21925     5
# Name: Order ID, Length: 793, dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Year',
#        'Quarter', 'Month', 'Weekday'],
#       dtype='object')

# %%
# Question 41: Find customers who placed only 1 order.
cust_order_1 = df.groupby('Customer ID')['Order ID'].nunique()
print(cust_order_1[cust_order_1 == 1])
# Out:
# Customer ID
# AO-10810    1
# AR-10570    1
# CJ-11875    1
# JC-15385    1
# JR-15700    1
# LD-16855    1
# MG-18205    1
# PH-18790    1
# RE-19405    1
# RM-19750    1
# SM-20905    1
# TC-21145    1
# Name: Order ID, dtype: int64

# %%
# Question 42: Find customers who placed more than 10 orders.
cust_10=df.groupby('Customer ID')['Order ID'].nunique()
print(cust_10[cust_10 > 10])
# Out:
# Customer ID
# AH-10690    12
# BD-11320    12
# BF-11170    11
# BM-11650    11
# BP-11095    12
# CC-12220    12
# CK-12205    13
# CK-12595    11
# CL-12565    12
# CS-11950    11
# CS-12250    12
# CS-12355    11
# DK-12835    12
# Dp-13240    11
# EA-14035    13
# EH-13765    12
# EP-13915    17
# GA-14725    11
# GB-14530    11
# GT-14710    11
# HG-14965    12
# JD-15895    11
# JE-15745    13
# JF-15490    11
# JG-15160    11
# JL-15835    11
# KB-16585    12
# KD-16495    12
# KL-16645    12
# LA-16780    11
# LC-16885    12
# MA-17560    11
# MM-17920    11
# MY-18295    11
# NS-18640    13
# PG-18820    13
# PK-19075    12
# PO-18850    11
# RB-19465    12
# RP-19390    12
# SC-20725    11
# SE-20110    11
# SH-19975    13
# SJ-20125    12
# SM-20950    12
# SZ-20035    11
# WB-21850    11
# XP-21865    11
# ZC-21910    13
# Name: Order ID, dtype: int64

# %%
# Question 43: Find total number of states represented.
print(df['State'].nunique())
print(df['State'].unique())
# Out:
# 49
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
# Question 44: Find total number of cities represented.
print(df['City'].nunique())
# Out:
# 531

# %%
# Question 45: Find number of orders placed from California.
print(df[df['State'] == 'California']['Order ID'].nunique())
# Out:
# 1021

# %%
# Question 46: Find number of orders placed from New York.
print(df[df['State'] == 'New York']['Order ID'].nunique())
# Out:
# 562

# %%
# Question 47: Find number of orders placed from Texas.
print(df[df['State'] == 'Texas']['Order ID'].nunique())
# Out:
# 487

# %%
# Question 48: Find number of orders placed from Florida.
print(df[df['State'] == 'Florida']['Order ID'].nunique())
# Out:
# 200

# %%
# Question 49: Find number of orders shipped after 5 days of order.
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Ship_Days'] = (df['Ship Date'] - df['Order Date']).dt.days
print(df[df['Ship_Days'] > 5]['Order ID'].nunique())
# Out:
# 904

# %%
# Question 50: Find average shipping time in days.
print(df['Ship_Days'].mean())
# Out:
# 3.958174904942966
